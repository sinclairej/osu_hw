# %% [markdown]
# # Astro 5830 HW1
# ### Starter Notebook for plotting spectra

# %%
from glob import glob
from astropy.io import ascii
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# matplotlib settings 
SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('lines', linewidth=2)
plt.rc('axes', linewidth=2)
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
lastname = 'jones'
files = glob(lastname+"*.txt")
print(files)
# Out:
# ['jones0.txt', 'jones4.txt', 'jones1.txt', 'jones2.txt', 'jones3.txt']

# %%
def plotspec(file):
    fig, ax = plt.subplots(1, 1, figsize=(12,8))
    spec = ascii.read(file)
    spec['col2'] = 1e12*spec['col2'] # rescale 
    ax.plot(spec['col1'], spec['col2'], 'k-', label=file)
    ax.legend(frameon=False, fontsize=BIGGER_SIZE)
    ax.set_xlabel(r'Wavelength ($\mathrm{\AA}$)')
    ax.set_ylabel('Flux')
    ax.set_xlim(3400, 5500)
    return ax

# %%
# red = strong, blue = weak
def plotO(ax=None):
    if ax is None:
        fig, ax = plt.subplots(1, 1, figsize=(12,8))
    #ax.axvline(4685.74,color='crimson',linestyle='dashed',zorder=10) #HeII
    #ax.axvline(4363.15,color='crimson',linestyle='dashed',zorder=10) #OIII
    #ax.axvline(4363.15,color='crimson',linestyle='dashed',zorder=10) #OIII
    ax.axvspan(4948.920,4978.920, alpha=0.4, color='crimson') #OIII1
    ax.axvspan(4996.850,5016.850, alpha=0.4, color='crimson') #OIII2
    return ax

# %%
def plotB(ax=None):
    if ax is None:
        fig, ax = plt.subplots(1, 1, figsize=(12,8))
    ax.axvline(3969.588,color='crimson',linestyle='dashed',zorder=10)
    return ax

# %%
def plotA(ax=None):
    if ax is None:
        fig, ax = plt.subplots(1, 1, figsize=(12,8))
    ax.axvline(3969.588,color='crimson',linestyle='dashed',zorder=10)
    return ax

# %%
def plotF(ax=None):
    if ax is None:
        fig, ax = plt.subplots(1, 1, figsize=(12,8))
    ax.axvline(3969.588,color='crimson',linestyle='dashed',zorder=10)
    return ax

# %%
def plotG(ax=None):
    if ax is None:
        fig, ax = plt.subplots(1, 1, figsize=(12,8))
    ax.axvline(3969.588,color='crimson',linestyle='dashed',zorder=10)
    return ax

# %%
def plotK(ax=None):
    if ax is None:
        fig, ax = plt.subplots(1, 1, figsize=(12,8))
    ax.axvline(3969.588,color='crimson',linestyle='dashed',zorder=10)
    return ax

# %%
def plotM(ax=None):
    if ax is None:
        fig, ax = plt.subplots(1, 1, figsize=(12,8))
    ax.axvline(3969.588,color='crimson',linestyle='dashed',zorder=10)
    return ax

# %%
#fig, bx = plt.subplots(1, 1, figsize=(12,8))
ax = plotspec('jones0.txt')
plotO(ax)
#ax.axvline(3969.588,color='crimson',linestyle='dashed',zorder=10)
#8498 Å, 8542 Å and 8662 Å.
# Out:
# <AxesSubplot:xlabel='Wavelength ($\\mathrm{\\AA}$)', ylabel='Flux'>

# %%
ax = plotspec('jones1.txt')
plotO(ax)
# Out:
# <AxesSubplot:xlabel='Wavelength ($\\mathrm{\\AA}$)', ylabel='Flux'>

# %%
ax = plotspec('jones2.txt')
plotO(ax)
# Out:
# <AxesSubplot:xlabel='Wavelength ($\\mathrm{\\AA}$)', ylabel='Flux'>

# %%
ax = plotspec('jones3.txt')
plotO(ax)
# Out:
# <AxesSubplot:xlabel='Wavelength ($\\mathrm{\\AA}$)', ylabel='Flux'>

# %%
ax = plotspec('jones4.txt')
plotO(ax)
# Out:
# <AxesSubplot:xlabel='Wavelength ($\\mathrm{\\AA}$)', ylabel='Flux'>
